# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv(r"C:\Users\007sa\Downloads\3.12.+Example.csv")

# %%
data.head(4)
# Out:
#    Satisfaction  Loyalty
# 0             4    -1.33
# 1             6    -0.28
# 2             5    -0.99
# 3             7    -0.29

# %%
plt.scatter(data['Satisfaction'],data['Loyalty'])
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
# Out:
# Text(0, 0.5, 'Loyalty')

# %%
x = data.copy()

# %%
kmeans = KMeans(2)

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
clusters = x.copy()
clusters['cluster_pred'] =  kmeans.fit_predict(x)

# %%
plt.scatter(clusters['Satisfaction'],clusters['Loyalty'],c=clusters['cluster_pred'],cmap='rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
# Out:
# Text(0, 0.5, 'Loyalty')

# %%
from sklearn import preprocessing
x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-0.93138063, -1.3318111 ],
#        [-0.15523011, -0.28117124],
#        [-0.54330537, -0.99160391],
#        [ 0.23284516, -0.29117733],
#        [-0.93138063,  1.05964534],
#        [-2.09560642, -1.6620122 ],
#        [ 1.39707095, -0.97159172],
#        [ 0.62092042, -0.32119561],
#        [ 0.62092042,  1.01962097],
#        [ 0.62092042,  0.67941378],
#        [ 1.39707095, -0.3412078 ],
#        [-0.54330537,  0.38923705],
#        [-0.54330537, -1.69203048],
#        [-1.70753116,  0.66940768],
#        [ 0.23284516,  0.26916393],
#        [ 1.00899568,  1.35982816],
#        [ 0.62092042,  1.37984035],
#        [ 0.23284516,  1.35982816],
#        [ 0.23284516, -0.3412078 ],
#        [ 1.00899568,  0.66940768],
#        [ 1.39707095,  1.17971847],
#        [-1.31945589, -1.69203048],
#        [-0.93138063,  1.03963316],
#        [-1.31945589, -0.96158562],
#        [-0.15523011,  1.02962706],
#        [ 1.00899568, -0.99160391],
#        [ 1.39707095,  0.36922486],
#        [ 1.00899568,  0.02901767],
#        [-1.31945589, -1.36182938],
#        [-0.54330537,  0.72944425]])

# %%
wcss = []
for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\007sa\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
wcss
# Out:
# [60.0,
#  29.818973034723147,
#  17.913349527387968,
#  10.24718180592842,
#  7.792695153937188,
#  6.549836791599331,
#  5.348079410290981,
#  4.4308003385195285,
#  3.687975963852466]

# %%
plt.plot(range(1,10),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
kmeans = KMeans(5)
kmeans_new = kmeans.fit(x_scaled)
clusters_new = x.copy()
clusters_new['cluster_pred'] = kmeans.fit_predict(x_scaled)

# %%
clusters_new
# Out:
#     Satisfaction  Loyalty  cluster_pred
# 0              4    -1.33             2
# 1              6    -0.28             0
# 2              5    -0.99             2
# 3              7    -0.29             0
# 4              4     1.06             3
# 5              1    -1.66             2
# 6             10    -0.97             4
# 7              8    -0.32             0
# 8              8     1.02             1
# 9              8     0.68             1
# 10            10    -0.34             4
# 11             5     0.39             3
# 12             5    -1.69             2
# 13             2     0.67             3
# 14             7     0.27             0
# 15             9     1.36             1
# 16             8     1.38             1
# 17             7     1.36             1
# 18             7    -0.34             0
# 19             9     0.67             1
# 20            10     1.18             1
# 21             3    -1.69             2
# 22             4     1.04             3
# 23             3    -0.96             2
# 24             6     1.03             3
# 25             9    -0.99             4
# 26            10     0.37             4
# 27             9     0.03             4
# 28             3    -1.36             2
# 29             5     0.73             3

# %%
plt.scatter(clusters_new['Satisfaction'],clusters_new['Loyalty'],c = clusters_new['cluster_pred'],cmap = 'rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyality')
# Out:
# Text(0, 0.5, 'Loyality')
